# %%
#Get data from URL
#import requests

#url = 'https://ucr.fbi.gov/crime-in-the-u.s/2013/crime-in-the-u.s.-2013/tables/1tabledatadecoverviewpdf/table_1_crime_in_the_united_states_by_volume_and_rate_per_100000_inhabitants_1994-2013.xls/output.xls'

#response = requests.get(url)
#print(response)

#dir(response)

# %%
import webget 

url = 'https://ucr.fbi.gov/crime-in-the-u.s/2013/crime-in-the-u.s.-2013/tables/1tabledatadecoverviewpdf/table_1_crime_in_the_united_states_by_volume_and_rate_per_100000_inhabitants_1994-2013.xls/output.xls'

#Download file
webget.download(url)
# Out:
# Vi er her - Klar til download
# ...
# '.\\output.xls'

# %%
import pandas as pd

# Load spreadsheet to python
excel_sheet = pd.ExcelFile('output.xls')
# Print the sheet names
print(x1.sheet_names)
#Load a sheet into a DataFrame by name: df
dataframe = excel_sheet.parse('13tbl01')
title = dataframe.iloc[0][0]

print(title)
# Out:
# ['13tbl01']
# Crime in the United States

# %%
df.iloc[2:23]
# Out:
#    Table 1                   Unnamed: 2               Unnamed: 3  \
# 2     Year  Population1  Violent\ncrime  Violent \ncrime \nrate
# 3     1994    260327021         1857670                    713.6
# 4     1995    262803276         1798792                    684.5
# 5     1996    265228572         1688540                    636.6
# 6     1997    267783607         1636096                      611
# 7     1998    270248003         1533887                    567.6
# 8     1999    272690813         1426044                      523
# 9     2000    281421906         1425486                    506.5
# 10   20013    285317559         1439480                    504.5
# 11    2002    287973924         1423677                    494.4
# 12    2003    290788976         1383676                    475.8
# 13    2004    293656842         1360088                    463.2
# 14    2005    296507061         1390745                      469
# ...

# %%
row = df.iloc[3:4]
row
# Out:
#   Table 1            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3    1994  260327021    1857670      713.6      23326          9     102216
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 14 Unnamed: 15  \
# 3       39.3     618949      237.8     ...         2712774      1042.1
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 3     7879812      3026.9     1539287       591.3         NaN         NaN
#
#   Unnamed: 22 Unnamed: 23
# 3         NaN         NaN
#
# [1 rows x 24 columns]

# %%
df.iloc[13:14]
# Out:
#    Table 1            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 13    2004  293656842    1360088      463.2      16148        5.5      95089
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 14 Unnamed: 15  \
# 13       32.4     401470      136.7     ...         2144446       730.3
#
#    Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 13     6937089      2362.3     1237851       421.5         NaN
#
#    Unnamed: 22 Unnamed: 23
# 13         NaN         NaN
#
# [1 rows x 24 columns]

# %%
df.iloc[22:23]
# Out:
#    Table 1            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 22    2013  316128839    1163146      367.9      14196        4.5      79770
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 14 Unnamed: 15  \
# 22       25.2     345031      109.1     ...         1928465         610
#
#    Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 22     6004453      1899.4      699594       221.3         NaN         NaN
#
#    Unnamed: 22 Unnamed: 23
# 22         NaN         NaN
#
# [1 rows x 24 columns]

# %%
row1994 = df.iloc[3:4]
row2004 = df.iloc[13:14]
row2013 = df.iloc[22:23]

#1994
crime1994 = (row1994['Unnamed: 2'] + row1994['Unnamed: 3'] + row1994['Unnamed: 4'] + row1994['Unnamed: 5'] 
      + row1994['Unnamed: 6'] + row1994['Unnamed: 7'] + row1994['Unnamed: 8'] + row1994['Unnamed: 9'] + row1994['Unnamed: 10'] 
      + row1994['Unnamed: 11'] +  row1994['Unnamed: 12'] + row1994['Unnamed: 13'] + row1994['Unnamed: 14'] + row1994['Unnamed: 15'] 
      + row1994['Unnamed: 16'])
print("The crime in 1994 was:", crime1994)


#2004
crime2004 = (row2004['Unnamed: 2'] + row2004['Unnamed: 3'] + row2004['Unnamed: 4'] + row2004['Unnamed: 5'] 
      + row2004['Unnamed: 6'] + row2004['Unnamed: 7'] + row2004['Unnamed: 8'] + row2004['Unnamed: 9'] + row2004['Unnamed: 10'] 
      + row2004['Unnamed: 11'] +  row2004['Unnamed: 12'] + row2004['Unnamed: 13'] + row2004['Unnamed: 14'] + row2004['Unnamed: 15'] 
      + row2004['Unnamed: 16'])
print("The crime in 2004 was:", crime2004)


#2013
crime2013 = (row2013['Unnamed: 2'] + row2013['Unnamed: 3'] + row2013['Unnamed: 4'] + row2013['Unnamed: 5'] 
      + row2013['Unnamed: 6'] + row2013['Unnamed: 7'] + row2013['Unnamed: 8'] + row2013['Unnamed: 9'] + row2013['Unnamed: 10'] 
      + row2013['Unnamed: 11'] +  row2013['Unnamed: 12'] + row2013['Unnamed: 13'] + row2013['Unnamed: 14'] + row2013['Unnamed: 15'] 
      + row2013['Unnamed: 16'])
print("The crime in 2013 was:", crime2013)
# Out:
# The crime in 1994 was: 3    2.64469e+07
# dtype: object
# The crime in 2004 was: 13    2.21263e+07
# dtype: object
# The crime in 2013 was: 22    1.88958e+07
# dtype: object

# %%
#Question 1
def crime_amount(start, end):
   if start > end:
       return "Crime has decreased"
   else:
       return "Crime has increased"

print(crime_amount(crime1994, crime2013))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-6b4240e27485> in <module>()
#       5        return "Crime has increased"
#       6
# ----> 7 print(crime_amount(crime1994, crime2013))
#
# <ipython-input-156-6b4240e27485> in crime_amount(start, end)
#       1 def crime_amount(start, end):
# ----> 2    if start > end:
#       3        return "Crime has decreased"
#       4    else:
#       5        return "Crime has increased"
#
# C:\AppDownloads\Anaconda\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     816             if not self._indexed_same(other):
#     817                 msg = 'Can only compare identically-labeled Series objects'
# --> 818                 raise ValueError(msg)
#     819             return self._constructor(na_op(self.values, other.values),
# ...
